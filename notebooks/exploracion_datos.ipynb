# %%
import pandas as pd
df = pd.read_csv("../data/raw/raw_afluencia_metro.csv")
df.head()
# Out:
#    _id                fecha    mes  anio     linea  estacion  tipo_pago  \
# 0    1  2021-01-01T00:00:00  Enero  2021  LÃ­nea 1  Balbuena     Boleto
# 1    2  2021-01-01T00:00:00  Enero  2021  LÃ­nea 1  Balbuena    Prepago
# 2    3  2021-01-01T00:00:00  Enero  2021  LÃ­nea 1  Balbuena  Gratuidad
# 3    4  2021-01-01T00:00:00  Enero  2021  LÃ­nea 1  Balderas     Boleto
# 4    5  2021-01-01T00:00:00  Enero  2021  LÃ­nea 1  Balderas    Prepago
#
#    afluencia
# 0       1848
# 1        790
# 2        325
# 3       1103
# 4        922
